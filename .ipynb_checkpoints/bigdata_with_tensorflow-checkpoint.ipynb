# %% [markdown]
# ## 要根据预创建的 Estimator 编写 TensorFlow 程序，您必须执行下列任务：
#
# - 创建一个或多个输入函数。
# - 定义模型的特征列。
# - 实例化 Estimator，指定特征列和各种超参数。
# - 在 Estimator 对象上调用一个或多个方法，传递适当的输入函数作为数据的来源。

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import argparse
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# import iris_data

# %% [markdown]
# # 获得训练数据

# %%
import pandas
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib
import pandas as pd

df = pd.read_csv('train_data/1_to_11_train_building.csv')
#打乱数据
for i in range(10):
    df=df.reindex(np.random.permutation(df.index))

# %%
df.head(4)
# Out:
#         Unnamed: 0  Unnamed: 0.1  loc_id                 time  count  weekday  \
# 1597          1597          1597       1  2017-03-10 02:00:00    122        4
# 43659        43659         43659       6  2017-08-20 00:00:00     41        6
# 3071          3071          3071       1  2017-05-17 13:00:00    520        2
# 138564      138564        138564      19  2017-01-29 01:00:00      1        6
#
#         stage  is_weekend  month  day  hour  building  cat
# 1597        0           0      3   10     2         1    1
# 43659       0           1      8   20     0         5    1
# 3071        1           0      5   17    13         1    1
# 138564      0           1      1   29     1        11    1

# %% [markdown]
# ### 各个建筑物人数分布

# %%
a=df['building'].value_counts()
a.sort_index().plot(kind='bar')

# %%
data_X = {'loc_id':df['loc_id'].values,'month':df['month'].values,
        'day':df['day'].values,'hour':df['hour'].values,
#           'stage':df['stage'].values,
         'weekday':df['weekday'].values,
         'is_weekend':df['is_weekend'].values,
          'building':df['building'].values,'cat':df['cat'].values
         }
data_y = {'count':df['count'].values}
df_train_X = pd.DataFrame(data=data_X)
df_train_y = pd.DataFrame(data=data_y)

# %%
df_train_X['building'] = df_train_X['building']-1
df_train_X['cat'] = df_train_X['cat']-1
df_train_X['day'] = df_train_X['day']-1
df_train_X['loc_id'] = df_train_X['loc_id']-1
df_train_X['month'] = df_train_X['month']-1

# %%
df_train_X.describe()
# Out:
#             building            cat            day           hour  \
# count  252013.000000  252013.000000  252013.000000  252013.000000
# mean        8.194680       0.602759      14.603687      11.525338
# std         5.329816       0.848723       8.823848       6.891378
# min         0.000000       0.000000       0.000000       0.000000
# 25%         3.000000       0.000000       7.000000       6.000000
# 50%         8.000000       0.000000      14.000000      12.000000
# 75%        13.000000       1.000000      22.000000      17.000000
# max        17.000000       2.000000      30.000000      23.000000
#
#           is_weekend         loc_id          month        weekday
# count  252013.000000  252013.000000  252013.000000  252013.000000
# mean        0.286156      15.973303       5.062279       3.004805
# std         0.451964       9.529865       3.173494       2.006589
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       8.000000       2.000000       1.000000
# 50%         0.000000      16.000000       5.000000       3.000000
# 75%         1.000000      24.000000       8.000000       5.000000
# max         1.000000      32.000000      10.000000       6.000000

# %%
# num_train = int(df_train_X.shape[0]/5)
num_train = df_train_X.shape[0]
x = df_train_X[:-10000]
y = df_train_y['count'][:-10000]

# %%
# 总的训练数据
num_train
# Out:
# 252013

# %% [markdown]
# ### 获得评测模型准确率的数据

# %%
x_eval = df_train_X[-10000:]
y_eval = df_train_y['count'][-10000:]

# %% [markdown]
# ### 获得预测数据

# %%
df = pd.read_csv('train_data/12_test_buiding.csv')

# %%
data_X_predict = {'loc_id':df['loc_id'].values,'month':df['month'].values,
        'day':df['day'].values,'hour':df['hour'].values,
#         'stage':df['stage'].values,
        'building':df['building'].values,'cat':df['cat'].values,
         'weekday':df['weekday'].values, 
         'is_weekend':df['is_weekend'].values
         }
df_test_X = pd.DataFrame(data=data_X_predict)

# %%
df_test_X['building'] = df_test_X['building']-1
df_test_X['cat'] = df_test_X['cat']-1
df_test_X['day'] = df_test_X['day']-1
df_test_X['loc_id'] = df_test_X['loc_id']-1
df_test_X['month'] = df_test_X['month']-1

# %%
x_predict = df_test_X

x_predict.describe()
# Out:
#            building           cat           day          hour    is_weekend  \
# count  24552.000000  24552.000000  24552.000000  24552.000000  24552.000000
# mean       8.212121      0.606061     15.000000     11.500000      0.322581
# std        5.330170      0.850664      8.944454      6.922328      0.467473
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      7.000000      5.750000      0.000000
# 50%        8.000000      0.000000     15.000000     11.500000      0.000000
# 75%       13.000000      1.000000     23.000000     17.250000      1.000000
# max       17.000000      2.000000     30.000000     23.000000      1.000000
#
#              loc_id    month       weekday
# count  24552.000000  24552.0  24552.000000
# mean      16.000000     11.0      3.193548
# std        9.522098      0.0      2.006793
# min        0.000000     11.0      0.000000
# 25%        8.000000     11.0      1.000000
# 50%       16.000000     11.0      3.000000
# 75%       24.000000     11.0      5.000000
# max       32.000000     11.0      6.000000

# %% [markdown]
# # 构造输入函数

# %%
#训练模型输入函数
my_input_fn = tf.estimator.inputs.pandas_input_fn(x,y,shuffle=True)
#验证数据集输入函数
input_fn_eval = tf.estimator.inputs.pandas_input_fn(x_eval,y_eval,shuffle=True)
#预测数据集输入函数
input_fn_predict = tf.estimator.inputs.pandas_input_fn(x_predict,shuffle=False)

# %% [markdown]
# # 构造特征列
#
# - 分类标志列
# - 交叉列
# - 嵌入列
#
# 其中嵌入列是DNN的输入特征列，分类标识列将月份等时间转换为独热编码，特别注意分桶的数量选择，例如0-12，分桶为13模型才不会报错，1-5的特征分桶为6，一次类推确定分桶的数字。
#
# 建议查看官方文档:https://tensorflow.google.cn/get_started/feature_columns#categorical_identity_column

# %%
my_feature_columns = []
# keys = ['day','hour','loc_id','month']

# for key in keys:
#     my_feature_columns.append(tf.feature_column.numeric_column(key=key))
day_idt = tf.feature_column.categorical_column_with_identity(key='day',num_buckets=31)
hour_idt = tf.feature_column.categorical_column_with_identity(key='hour',num_buckets=24)
loc_idt = tf.feature_column.categorical_column_with_identity(key='loc_id',num_buckets=33)
building_idt = tf.feature_column.categorical_column_with_identity(key='building',num_buckets=18)
cat_idt = tf.feature_column.categorical_column_with_identity(key='cat',num_buckets=3)
# 测试数据和预测数据一共12个月所以用12+1个桶
month_idt = tf.feature_column.categorical_column_with_identity(key='month',num_buckets=13)
stage_idt = tf.feature_column.categorical_column_with_identity(key='stage',num_buckets=3)

is_weekend_idt = tf.feature_column.categorical_column_with_identity(key='is_weekend',num_buckets=2)
weekday_idt = tf.feature_column.categorical_column_with_identity(key='weekday',num_buckets=7)

# %% [markdown]
# #### 添加cross feature
#
# 将两个特征组合交叉产生新的特征，详情：https://tensorflow.google.cn/get_started/feature_columns#crossed_column

# %%
weekday_x_isWeekend = tf.feature_column.crossed_column([weekday_idt, is_weekend_idt],15)

# %% [markdown]
# #### 添加embedding feature
#
# DNN的常用输入特征，详情见：https://tensorflow.google.cn/get_started/feature_columns#indicator_and_embedding_columns

# %%
day_emb = tf.feature_column.embedding_column(day_idt,3)
hour_emb = tf.feature_column.embedding_column(hour_idt,3)
loc_emb = tf.feature_column.embedding_column(loc_idt,3)
month_emb = tf.feature_column.embedding_column(month_idt,3)
#stage_emb = tf.feature_column.embedding_column(stage_idt,2)
# is_weekend_emb = tf.feature_column.embedding_column(is_weekend_idt,2)
# weekday_emb = tf.feature_column.embedding_column(weekday_idt,2)
# 添加cross到embedding
weekday_x_isWeekend_emb = tf.feature_column.embedding_column(weekday_x_isWeekend, 2)

building_emb = tf.feature_column.embedding_column(building_idt,3)
cat_emb = tf.feature_column.embedding_column(cat_idt,2)

# %%
# DNN特征列
my_feature_columns = [day_emb, hour_emb, loc_emb, month_emb,
                      
#                       is_weekend_emb, weekday_emb,
                      weekday_x_isWeekend_emb,
                     building_emb, cat_emb]

# %%
my_feature_columns
# Out:
# [_EmbeddingColumn(categorical_column=_IdentityCategoricalColumn(key='day', num_buckets=31, default_value=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f85a6a6cd30>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True),
#  _EmbeddingColumn(categorical_column=_IdentityCategoricalColumn(key='hour', num_buckets=24, default_value=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f85a6a6cd68>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True),
#  _EmbeddingColumn(categorical_column=_IdentityCategoricalColumn(key='loc_id', num_buckets=33, default_value=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f85a6a6cc50>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True),
#  _EmbeddingColumn(categorical_column=_IdentityCategoricalColumn(key='month', num_buckets=13, default_value=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f85a6a6cc88>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True),
#  _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_IdentityCategoricalColumn(key='weekday', num_buckets=7, default_value=None), _IdentityCategoricalColumn(key='is_weekend', num_buckets=2, default_value=None)), hash_bucket_size=15, hash_key=None), dimension=2, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f85a6a6cba8>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True),
#  _EmbeddingColumn(categorical_column=_IdentityCategoricalColumn(key='building', num_buckets=18, default_value=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f85a6a6cda0>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True),
#  _EmbeddingColumn(categorical_column=_IdentityCategoricalColumn(key='cat', num_buckets=3, default_value=None), dimension=2, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f85a6a6ce10>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True)]

# %% [markdown]
# # 选择DNN回归模型

# %%
clf = tf.estimator.DNNRegressor(
    feature_columns=my_feature_columns,
#     hidden_units=[23760/2,5120,51200,2048])
#     hidden_units=[120000,10240,10240,5120]
   hidden_units=[4096,1024,256])
#     hidden_units=[4096*2,512*2])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpc87t9hn0
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpc87t9hn0', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f85a6a6c588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# # 训练模型、评测、预测

# %%
# for i in range(50000):
for i in range(10):
    clf.train(input_fn=my_input_fn,steps=10000)

# 小的step测试输入函数是否能正确预测
# clf.train(input_fn=my_input_fn,steps=10)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 38006950.0, step = 1
# INFO:tensorflow:global_step/sec: 22.9157
# INFO:tensorflow:loss = 12801319.0, step = 101 (4.365 sec)
# INFO:tensorflow:global_step/sec: 24.7623
# INFO:tensorflow:loss = 4638922.0, step = 201 (4.039 sec)
# INFO:tensorflow:global_step/sec: 22.6194
# INFO:tensorflow:loss = 4008552.0, step = 301 (4.421 sec)
# INFO:tensorflow:global_step/sec: 23.057
# INFO:tensorflow:loss = 4203592.0, step = 401 (4.337 sec)
# INFO:tensorflow:global_step/sec: 21.154
# INFO:tensorflow:loss = 11228900.0, step = 501 (4.727 sec)
# INFO:tensorflow:global_step/sec: 22.4997
# INFO:tensorflow:loss = 3154172.0, step = 601 (4.444 sec)
# INFO:tensorflow:global_step/sec: 21.9041
# INFO:tensorflow:loss = 9703152.0, step = 701 (4.565 sec)
# INFO:tensorflow:global_step/sec: 23.5774
# INFO:tensorflow:loss = 4700459.0, step = 801 (4.241 sec)
# INFO:tensorflow:global_step/sec: 22.5007
# INFO:tensorflow:loss = 1996994.2, step = 901 (4.444 sec)
# INFO:tensorflow:global_step/sec: 24.6702
# INFO:tensorflow:loss = 7388131.0, step = 1001 (4.053 sec)
# INFO:tensorflow:global_step/sec: 24.7615
# INFO:tensorflow:loss = 12872506.0, step = 1101 (4.039 sec)
# INFO:tensorflow:global_step/sec: 22.576
# INFO:tensorflow:loss = 3375071.0, step = 1201 (4.430 sec)
# INFO:tensorflow:global_step/sec: 20.8513
# INFO:tensorflow:loss = 3283669.0, step = 1301 (4.796 sec)
# INFO:tensorflow:global_step/sec: 22.7506
# INFO:tensorflow:loss = 5750727.0, step = 1401 (4.396 sec)
# INFO:tensorflow:global_step/sec: 24.0878
# INFO:tensorflow:loss = 3601802.0, step = 1501 (4.152 sec)
# INFO:tensorflow:global_step/sec: 22.9227
# INFO:tensorflow:loss = 4715202.5, step = 1601 (4.362 sec)
# INFO:tensorflow:global_step/sec: 20.0056
# INFO:tensorflow:loss = 2745132.0, step = 1701 (4.999 sec)
# INFO:tensorflow:global_step/sec: 21.3091
# INFO:tensorflow:loss = 2397659.0, step = 1801 (4.692 sec)
# INFO:tensorflow:Saving checkpoints for 1891 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 2291693.5.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-1891
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1892 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 3337081.0, step = 1892
# INFO:tensorflow:global_step/sec: 21.063
# INFO:tensorflow:loss = 3342218.5, step = 1992 (4.749 sec)
# INFO:tensorflow:global_step/sec: 22.6513
# INFO:tensorflow:loss = 6346884.0, step = 2092 (4.415 sec)
# INFO:tensorflow:global_step/sec: 21.3447
# INFO:tensorflow:loss = 2612865.5, step = 2192 (4.685 sec)
# INFO:tensorflow:global_step/sec: 20.953
# INFO:tensorflow:loss = 3735786.0, step = 2292 (4.773 sec)
# INFO:tensorflow:global_step/sec: 22.0262
# INFO:tensorflow:loss = 6476319.0, step = 2392 (4.540 sec)
# INFO:tensorflow:global_step/sec: 21.6214
# INFO:tensorflow:loss = 2805792.0, step = 2492 (4.625 sec)
# INFO:tensorflow:global_step/sec: 23.2613
# INFO:tensorflow:loss = 3890130.0, step = 2592 (4.299 sec)
# INFO:tensorflow:global_step/sec: 19.5796
# INFO:tensorflow:loss = 4346159.0, step = 2692 (5.108 sec)
# INFO:tensorflow:global_step/sec: 20.88
# INFO:tensorflow:loss = 3634596.0, step = 2792 (4.792 sec)
# INFO:tensorflow:global_step/sec: 21.5913
# INFO:tensorflow:loss = 4104706.0, step = 2892 (4.629 sec)
# INFO:tensorflow:global_step/sec: 20.5652
# INFO:tensorflow:loss = 4192276.8, step = 2992 (4.862 sec)
# INFO:tensorflow:global_step/sec: 21.9588
# INFO:tensorflow:loss = 2723693.5, step = 3092 (4.554 sec)
# INFO:tensorflow:global_step/sec: 21.0276
# INFO:tensorflow:loss = 4325392.5, step = 3192 (4.756 sec)
# INFO:tensorflow:global_step/sec: 21.3208
# INFO:tensorflow:loss = 6972987.5, step = 3292 (4.690 sec)
# INFO:tensorflow:global_step/sec: 19.5182
# INFO:tensorflow:loss = 2359649.0, step = 3392 (5.124 sec)
# INFO:tensorflow:global_step/sec: 19.2172
# INFO:tensorflow:loss = 3112122.5, step = 3492 (5.203 sec)
# INFO:tensorflow:global_step/sec: 23.5962
# INFO:tensorflow:loss = 8074695.5, step = 3592 (4.238 sec)
# INFO:tensorflow:global_step/sec: 22.1141
# INFO:tensorflow:loss = 2704371.0, step = 3692 (4.522 sec)
# INFO:tensorflow:Saving checkpoints for 3782 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 2118757.5.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-3782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3783 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 2821104.8, step = 3783
# INFO:tensorflow:global_step/sec: 22.0033
# INFO:tensorflow:loss = 1929095.0, step = 3883 (4.546 sec)
# INFO:tensorflow:global_step/sec: 22.9183
# INFO:tensorflow:loss = 5119368.0, step = 3983 (4.363 sec)
# INFO:tensorflow:global_step/sec: 21.474
# INFO:tensorflow:loss = 3791636.5, step = 4083 (4.657 sec)
# INFO:tensorflow:global_step/sec: 21.7514
# INFO:tensorflow:loss = 4323252.0, step = 4183 (4.597 sec)
# INFO:tensorflow:global_step/sec: 21.953
# INFO:tensorflow:loss = 4502621.5, step = 4283 (4.555 sec)
# INFO:tensorflow:global_step/sec: 20.8768
# INFO:tensorflow:loss = 6010036.5, step = 4383 (4.790 sec)
# INFO:tensorflow:global_step/sec: 22.668
# INFO:tensorflow:loss = 2657100.8, step = 4483 (4.411 sec)
# INFO:tensorflow:global_step/sec: 21.2092
# INFO:tensorflow:loss = 3908116.0, step = 4583 (4.715 sec)
# INFO:tensorflow:global_step/sec: 22.7437
# INFO:tensorflow:loss = 2417368.0, step = 4683 (4.397 sec)
# INFO:tensorflow:global_step/sec: 21.3267
# INFO:tensorflow:loss = 3328125.8, step = 4783 (4.689 sec)
# INFO:tensorflow:global_step/sec: 20.853
# INFO:tensorflow:loss = 3136153.0, step = 4883 (4.796 sec)
# INFO:tensorflow:global_step/sec: 21.3238
# INFO:tensorflow:loss = 2998503.0, step = 4983 (4.689 sec)
# INFO:tensorflow:global_step/sec: 19.5003
# INFO:tensorflow:loss = 1598033.2, step = 5083 (5.128 sec)
# INFO:tensorflow:global_step/sec: 21.5059
# INFO:tensorflow:loss = 2042737.9, step = 5183 (4.650 sec)
# INFO:tensorflow:global_step/sec: 19.9439
# INFO:tensorflow:loss = 1760085.0, step = 5283 (5.017 sec)
# INFO:tensorflow:global_step/sec: 17.5294
# INFO:tensorflow:loss = 3745445.2, step = 5383 (5.701 sec)
# INFO:tensorflow:global_step/sec: 20.337
# INFO:tensorflow:loss = 2637215.0, step = 5483 (4.917 sec)
# INFO:tensorflow:global_step/sec: 22.8382
# INFO:tensorflow:loss = 3757475.0, step = 5583 (4.379 sec)
# INFO:tensorflow:Saving checkpoints for 5673 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 2076554.5.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-5673
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5674 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 2715021.5, step = 5674
# INFO:tensorflow:global_step/sec: 21.4886
# INFO:tensorflow:loss = 12170500.0, step = 5774 (4.655 sec)
# INFO:tensorflow:global_step/sec: 22.6194
# INFO:tensorflow:loss = 2693944.5, step = 5874 (4.422 sec)
# INFO:tensorflow:global_step/sec: 21.3258
# INFO:tensorflow:loss = 2630347.0, step = 5974 (4.688 sec)
# INFO:tensorflow:global_step/sec: 22.0052
# INFO:tensorflow:loss = 1745607.6, step = 6074 (4.544 sec)
# INFO:tensorflow:global_step/sec: 23.0032
# INFO:tensorflow:loss = 3746020.0, step = 6174 (4.347 sec)
# INFO:tensorflow:global_step/sec: 22.2292
# INFO:tensorflow:loss = 3418669.0, step = 6274 (4.499 sec)
# INFO:tensorflow:global_step/sec: 22.3981
# INFO:tensorflow:loss = 2208037.8, step = 6374 (4.465 sec)
# INFO:tensorflow:global_step/sec: 21.4354
# INFO:tensorflow:loss = 2270084.2, step = 6474 (4.665 sec)
# INFO:tensorflow:global_step/sec: 22.3135
# INFO:tensorflow:loss = 2037013.1, step = 6574 (4.481 sec)
# INFO:tensorflow:global_step/sec: 20.8511
# INFO:tensorflow:loss = 2053540.2, step = 6674 (4.796 sec)
# INFO:tensorflow:global_step/sec: 20.6663
# INFO:tensorflow:loss = 5232290.5, step = 6774 (4.839 sec)
# INFO:tensorflow:global_step/sec: 20.3764
# INFO:tensorflow:loss = 1783468.9, step = 6874 (4.908 sec)
# INFO:tensorflow:global_step/sec: 19.0264
# INFO:tensorflow:loss = 2812126.0, step = 6974 (5.256 sec)
# INFO:tensorflow:global_step/sec: 23.1397
# INFO:tensorflow:loss = 2467288.0, step = 7074 (4.321 sec)
# INFO:tensorflow:global_step/sec: 21.8608
# INFO:tensorflow:loss = 3148057.5, step = 7174 (4.574 sec)
# INFO:tensorflow:global_step/sec: 22.8399
# INFO:tensorflow:loss = 1625574.6, step = 7274 (4.378 sec)
# INFO:tensorflow:global_step/sec: 22.8403
# INFO:tensorflow:loss = 1839564.4, step = 7374 (4.378 sec)
# INFO:tensorflow:global_step/sec: 22.3774
# INFO:tensorflow:loss = 2814889.5, step = 7474 (4.469 sec)
# INFO:tensorflow:Saving checkpoints for 7564 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 2339101.5.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-7564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7565 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 1976817.2, step = 7565
# INFO:tensorflow:global_step/sec: 22.8248
# INFO:tensorflow:loss = 3423863.8, step = 7665 (4.382 sec)
# INFO:tensorflow:global_step/sec: 23.4619
# INFO:tensorflow:loss = 1484310.5, step = 7765 (4.262 sec)
# INFO:tensorflow:global_step/sec: 22.899
# INFO:tensorflow:loss = 1629480.9, step = 7865 (4.367 sec)
# INFO:tensorflow:global_step/sec: 22.2284
# INFO:tensorflow:loss = 2614673.8, step = 7965 (4.499 sec)
# INFO:tensorflow:global_step/sec: 23.3395
# INFO:tensorflow:loss = 3486984.5, step = 8065 (4.285 sec)
# INFO:tensorflow:global_step/sec: 21.9348
# INFO:tensorflow:loss = 1598930.5, step = 8165 (4.559 sec)
# INFO:tensorflow:global_step/sec: 24.0971
# INFO:tensorflow:loss = 1692362.2, step = 8265 (4.150 sec)
# INFO:tensorflow:global_step/sec: 21.7765
# INFO:tensorflow:loss = 2062933.5, step = 8365 (4.592 sec)
# INFO:tensorflow:global_step/sec: 22.2279
# INFO:tensorflow:loss = 2489575.0, step = 8465 (4.499 sec)
# INFO:tensorflow:global_step/sec: 19.931
# INFO:tensorflow:loss = 1954350.5, step = 8565 (5.018 sec)
# INFO:tensorflow:global_step/sec: 21.7861
# INFO:tensorflow:loss = 1814484.5, step = 8665 (4.590 sec)
# INFO:tensorflow:global_step/sec: 22.8312
# INFO:tensorflow:loss = 1432976.8, step = 8765 (4.379 sec)
# INFO:tensorflow:global_step/sec: 21.7799
# INFO:tensorflow:loss = 2943042.0, step = 8865 (4.592 sec)
# INFO:tensorflow:global_step/sec: 22.5898
# INFO:tensorflow:loss = 2195886.5, step = 8965 (4.427 sec)
# INFO:tensorflow:global_step/sec: 21.0519
# INFO:tensorflow:loss = 3231038.0, step = 9065 (4.751 sec)
# INFO:tensorflow:global_step/sec: 20.9035
# INFO:tensorflow:loss = 3750661.2, step = 9165 (4.784 sec)
# INFO:tensorflow:global_step/sec: 21.4457
# INFO:tensorflow:loss = 1759429.6, step = 9265 (4.663 sec)
# INFO:tensorflow:global_step/sec: 22.5293
# INFO:tensorflow:loss = 2144905.0, step = 9365 (4.439 sec)
# INFO:tensorflow:Saving checkpoints for 9455 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 3004840.8.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-9455
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9456 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 3232750.5, step = 9456
# INFO:tensorflow:global_step/sec: 21.4089
# INFO:tensorflow:loss = 1210025.4, step = 9556 (4.672 sec)
# INFO:tensorflow:global_step/sec: 21.3432
# INFO:tensorflow:loss = 1588495.5, step = 9656 (4.686 sec)
# INFO:tensorflow:global_step/sec: 18.4922
# INFO:tensorflow:loss = 2294755.0, step = 9756 (5.408 sec)
# INFO:tensorflow:global_step/sec: 18.351
# INFO:tensorflow:loss = 1668314.5, step = 9856 (5.449 sec)
# INFO:tensorflow:global_step/sec: 22.1168
# INFO:tensorflow:loss = 1911055.5, step = 9956 (4.521 sec)
# INFO:tensorflow:global_step/sec: 21.9467
# INFO:tensorflow:loss = 1689161.9, step = 10056 (4.557 sec)
# INFO:tensorflow:global_step/sec: 21.5728
# INFO:tensorflow:loss = 6318457.0, step = 10156 (4.635 sec)
# INFO:tensorflow:global_step/sec: 20.7295
# INFO:tensorflow:loss = 3517231.0, step = 10256 (4.824 sec)
# INFO:tensorflow:global_step/sec: 21.0558
# INFO:tensorflow:loss = 3437142.0, step = 10356 (4.749 sec)
# INFO:tensorflow:global_step/sec: 21.7174
# INFO:tensorflow:loss = 2659134.0, step = 10456 (4.605 sec)
# INFO:tensorflow:global_step/sec: 21.9209
# INFO:tensorflow:loss = 2871232.2, step = 10556 (4.562 sec)
# INFO:tensorflow:global_step/sec: 22.466
# INFO:tensorflow:loss = 1483623.0, step = 10656 (4.452 sec)
# INFO:tensorflow:global_step/sec: 22.5146
# INFO:tensorflow:loss = 2325185.8, step = 10756 (4.441 sec)
# INFO:tensorflow:global_step/sec: 21.7819
# INFO:tensorflow:loss = 1713130.2, step = 10856 (4.591 sec)
# INFO:tensorflow:global_step/sec: 19.9423
# INFO:tensorflow:loss = 2593312.8, step = 10956 (5.015 sec)
# INFO:tensorflow:global_step/sec: 20.8212
# INFO:tensorflow:loss = 2171856.8, step = 11056 (4.803 sec)
# INFO:tensorflow:global_step/sec: 23.0934
# INFO:tensorflow:loss = 2985321.2, step = 11156 (4.331 sec)
# INFO:tensorflow:global_step/sec: 22.3318
# INFO:tensorflow:loss = 2812476.0, step = 11256 (4.478 sec)
# INFO:tensorflow:Saving checkpoints for 11346 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 1674788.5.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-11346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 11347 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 2331623.5, step = 11347
# INFO:tensorflow:global_step/sec: 21.761
# INFO:tensorflow:loss = 1634176.1, step = 11447 (4.596 sec)
# INFO:tensorflow:global_step/sec: 22.165
# INFO:tensorflow:loss = 5792167.5, step = 11547 (4.512 sec)
# INFO:tensorflow:global_step/sec: 21.9856
# INFO:tensorflow:loss = 1839695.9, step = 11647 (4.548 sec)
# INFO:tensorflow:global_step/sec: 21.0135
# INFO:tensorflow:loss = 2493848.0, step = 11747 (4.759 sec)
# INFO:tensorflow:global_step/sec: 22.6893
# INFO:tensorflow:loss = 3341397.0, step = 11847 (4.407 sec)
# INFO:tensorflow:global_step/sec: 21.3945
# INFO:tensorflow:loss = 1205098.0, step = 11947 (4.674 sec)
# INFO:tensorflow:global_step/sec: 22.9002
# INFO:tensorflow:loss = 1759047.1, step = 12047 (4.367 sec)
# INFO:tensorflow:global_step/sec: 21.4287
# INFO:tensorflow:loss = 999614.06, step = 12147 (4.667 sec)
# INFO:tensorflow:global_step/sec: 22.5222
# INFO:tensorflow:loss = 1693729.8, step = 12247 (4.440 sec)
# INFO:tensorflow:global_step/sec: 22.1458
# INFO:tensorflow:loss = 2508014.0, step = 12347 (4.516 sec)
# INFO:tensorflow:global_step/sec: 22.1109
# INFO:tensorflow:loss = 2199935.0, step = 12447 (4.523 sec)
# INFO:tensorflow:global_step/sec: 23.1033
# INFO:tensorflow:loss = 2768791.5, step = 12547 (4.328 sec)
# INFO:tensorflow:global_step/sec: 21.1311
# INFO:tensorflow:loss = 2100073.8, step = 12647 (4.732 sec)
# INFO:tensorflow:global_step/sec: 23.8799
# INFO:tensorflow:loss = 3010507.5, step = 12747 (4.188 sec)
# INFO:tensorflow:global_step/sec: 21.8766
# INFO:tensorflow:loss = 1396520.1, step = 12847 (4.571 sec)
# INFO:tensorflow:global_step/sec: 22.6056
# INFO:tensorflow:loss = 2747364.0, step = 12947 (4.424 sec)
# INFO:tensorflow:global_step/sec: 20.2758
# INFO:tensorflow:loss = 2536323.8, step = 13047 (4.932 sec)
# INFO:tensorflow:global_step/sec: 22.2162
# INFO:tensorflow:loss = 4510992.0, step = 13147 (4.501 sec)
# INFO:tensorflow:Saving checkpoints for 13237 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 2435945.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-13237
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13238 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 1834543.8, step = 13238
# INFO:tensorflow:global_step/sec: 22.8308
# INFO:tensorflow:loss = 2697305.5, step = 13338 (4.381 sec)
# INFO:tensorflow:global_step/sec: 22.5733
# INFO:tensorflow:loss = 3168470.5, step = 13438 (4.431 sec)
# INFO:tensorflow:global_step/sec: 21.9319
# INFO:tensorflow:loss = 2157463.0, step = 13538 (4.559 sec)
# INFO:tensorflow:global_step/sec: 22.0923
# INFO:tensorflow:loss = 987125.6, step = 13638 (4.527 sec)
# INFO:tensorflow:global_step/sec: 23.6846
# INFO:tensorflow:loss = 1749257.5, step = 13738 (4.222 sec)
# INFO:tensorflow:global_step/sec: 21.9298
# INFO:tensorflow:loss = 1510577.4, step = 13838 (4.560 sec)
# INFO:tensorflow:global_step/sec: 24.2438
# INFO:tensorflow:loss = 1628906.2, step = 13938 (4.125 sec)
# INFO:tensorflow:global_step/sec: 21.9072
# INFO:tensorflow:loss = 1665125.5, step = 14038 (4.565 sec)
# INFO:tensorflow:global_step/sec: 23.6052
# INFO:tensorflow:loss = 2343804.8, step = 14138 (4.236 sec)
# INFO:tensorflow:global_step/sec: 22.6123
# INFO:tensorflow:loss = 1481910.0, step = 14238 (4.422 sec)
# INFO:tensorflow:global_step/sec: 23.1636
# INFO:tensorflow:loss = 4523344.5, step = 14338 (4.317 sec)
# INFO:tensorflow:global_step/sec: 22.3255
# INFO:tensorflow:loss = 2788447.5, step = 14438 (4.479 sec)
# INFO:tensorflow:global_step/sec: 22.5795
# INFO:tensorflow:loss = 3063859.5, step = 14538 (4.429 sec)
# INFO:tensorflow:global_step/sec: 22.7281
# INFO:tensorflow:loss = 5146762.0, step = 14638 (4.400 sec)
# INFO:tensorflow:global_step/sec: 21.6288
# INFO:tensorflow:loss = 1117319.8, step = 14738 (4.624 sec)
# INFO:tensorflow:global_step/sec: 23.5101
# INFO:tensorflow:loss = 4304016.0, step = 14838 (4.255 sec)
# INFO:tensorflow:global_step/sec: 21.6154
# INFO:tensorflow:loss = 1829728.0, step = 14938 (4.625 sec)
# INFO:tensorflow:global_step/sec: 23.5464
# INFO:tensorflow:loss = 2069824.4, step = 15038 (4.247 sec)
# INFO:tensorflow:Saving checkpoints for 15128 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 943819.3.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-15128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15129 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 1649119.2, step = 15129
# INFO:tensorflow:global_step/sec: 21.718
# INFO:tensorflow:loss = 2281414.2, step = 15229 (4.605 sec)
# INFO:tensorflow:global_step/sec: 23.5378
# INFO:tensorflow:loss = 2113384.8, step = 15329 (4.249 sec)
# INFO:tensorflow:global_step/sec: 20.6757
# INFO:tensorflow:loss = 1231833.2, step = 15429 (4.837 sec)
# INFO:tensorflow:global_step/sec: 22.83
# INFO:tensorflow:loss = 1897496.8, step = 15529 (4.380 sec)
# INFO:tensorflow:global_step/sec: 22.6612
# INFO:tensorflow:loss = 1582933.2, step = 15629 (4.413 sec)
# INFO:tensorflow:global_step/sec: 23.3073
# INFO:tensorflow:loss = 1799452.6, step = 15729 (4.291 sec)
# INFO:tensorflow:global_step/sec: 22.0226
# INFO:tensorflow:loss = 1207392.1, step = 15829 (4.541 sec)
# INFO:tensorflow:global_step/sec: 23.6112
# INFO:tensorflow:loss = 4668176.5, step = 15929 (4.235 sec)
# INFO:tensorflow:global_step/sec: 21.4496
# INFO:tensorflow:loss = 2003523.0, step = 16029 (4.662 sec)
# INFO:tensorflow:global_step/sec: 24.2
# INFO:tensorflow:loss = 1465141.1, step = 16129 (4.132 sec)
# INFO:tensorflow:global_step/sec: 22.3164
# INFO:tensorflow:loss = 1384908.2, step = 16229 (4.481 sec)
# INFO:tensorflow:global_step/sec: 23.9263
# INFO:tensorflow:loss = 1491302.5, step = 16329 (4.180 sec)
# INFO:tensorflow:global_step/sec: 22.6637
# INFO:tensorflow:loss = 2227091.5, step = 16429 (4.412 sec)
# INFO:tensorflow:global_step/sec: 23.0196
# INFO:tensorflow:loss = 2576392.2, step = 16529 (4.344 sec)
# INFO:tensorflow:global_step/sec: 22.9625
# INFO:tensorflow:loss = 1871223.0, step = 16629 (4.355 sec)
# INFO:tensorflow:global_step/sec: 22.7341
# INFO:tensorflow:loss = 1974737.5, step = 16729 (4.399 sec)
# INFO:tensorflow:global_step/sec: 23.6339
# INFO:tensorflow:loss = 1694323.8, step = 16829 (4.231 sec)
# INFO:tensorflow:global_step/sec: 22.5681
# INFO:tensorflow:loss = 4347441.0, step = 16929 (4.431 sec)
# INFO:tensorflow:Saving checkpoints for 17019 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 1548629.1.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpc87t9hn0/model.ckpt-17019
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 17020 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:loss = 1761719.1, step = 17020
# INFO:tensorflow:global_step/sec: 22.8784
# INFO:tensorflow:loss = 1728398.2, step = 17120 (4.372 sec)
# INFO:tensorflow:global_step/sec: 23.2258
# INFO:tensorflow:loss = 2434920.0, step = 17220 (4.306 sec)
# INFO:tensorflow:global_step/sec: 22.5637
# INFO:tensorflow:loss = 1276970.0, step = 17320 (4.432 sec)
# INFO:tensorflow:global_step/sec: 21.7716
# INFO:tensorflow:loss = 1980755.9, step = 17420 (4.593 sec)
# INFO:tensorflow:global_step/sec: 23.1223
# INFO:tensorflow:loss = 1522867.8, step = 17520 (4.325 sec)
# INFO:tensorflow:global_step/sec: 20.0467
# INFO:tensorflow:loss = 3033728.0, step = 17620 (4.988 sec)
# INFO:tensorflow:global_step/sec: 18.8344
# INFO:tensorflow:loss = 1584170.2, step = 17720 (5.309 sec)
# INFO:tensorflow:global_step/sec: 21.7727
# INFO:tensorflow:loss = 940970.9, step = 17820 (4.593 sec)
# INFO:tensorflow:global_step/sec: 20.4446
# INFO:tensorflow:loss = 1957607.0, step = 17920 (4.891 sec)
# INFO:tensorflow:global_step/sec: 21.772
# INFO:tensorflow:loss = 1652537.5, step = 18020 (4.593 sec)
# INFO:tensorflow:global_step/sec: 20.7275
# INFO:tensorflow:loss = 1860499.0, step = 18120 (4.825 sec)
# INFO:tensorflow:global_step/sec: 22.3171
# INFO:tensorflow:loss = 2225375.2, step = 18220 (4.481 sec)
# INFO:tensorflow:global_step/sec: 20.8803
# INFO:tensorflow:loss = 1053248.1, step = 18320 (4.789 sec)
# INFO:tensorflow:global_step/sec: 21.8089
# INFO:tensorflow:loss = 1937040.5, step = 18420 (4.585 sec)
# INFO:tensorflow:global_step/sec: 23.4268
# INFO:tensorflow:loss = 1199933.2, step = 18520 (4.269 sec)
# INFO:tensorflow:global_step/sec: 22.1578
# INFO:tensorflow:loss = 1837164.0, step = 18620 (4.513 sec)
# INFO:tensorflow:global_step/sec: 23.3281
# INFO:tensorflow:loss = 2544961.5, step = 18720 (4.287 sec)
# INFO:tensorflow:global_step/sec: 21.5207
# INFO:tensorflow:loss = 4987984.0, step = 18820 (4.647 sec)
# INFO:tensorflow:Saving checkpoints for 18910 into /tmp/tmpc87t9hn0/model.ckpt.
# INFO:tensorflow:Loss for final step: 823990.06.

# %% [markdown]
# # 模型评估
# ### 所有数据集训练完成后各个模型的准确率
# - 线性回归 average_loss：72943
# - SVM average_loss：10000
# - DNN average_loss：3000

# %%
clf.evaluate(input_fn=input_fn_eval,steps=10000)

# %% [markdown]
# # 模型预测

# %% [markdown]
# ### 将预测的数据保存到列表中

# %%
res = clf.predict(input_fn=input_fn_predict)
ans_list = []
for line in res:
    ans_list.append(line['predictions'][0])

# %% [markdown]
# ### 生成提交数据

# %%
y = pd.DataFrame({'col':[e for e in ans_list]})
y = pd.DataFrame({'col':[e for e in ans_list]})
y.head()

# %%
y.describe()

# %%
df_y = pd.read_csv('test_data_12')

# %%
df_y.describe()

# %% [markdown]
# ### 画图查看预测的数据是否有异常

# %%
fig, axes =plt.subplots(nrows=2, ncols=2,figsize=(20, 10))
y[:50].plot(ax=axes[0,0])
axes[0,0].set_title('50')
axes[0,1].set_title('500')
axes[1,0].set_title('1000')
axes[1,1].set_title('10000')
y[:100].plot(ax=axes[0,1])
y[:1000].plot(ax=axes[1,0])
y[:10000].plot(ax=axes[1,1])

# %% [markdown]
# ### 将数据中小于0的转化为0

# %%
y_list = y.values.tolist()

y_remove_0 = []
for e in ans_list:
    if e<0:
        y_remove_0.append(0);
    else:
        y_remove_0.append(e)
y=y_remove_0

# %% [markdown]
# #### 合并测试数据和预测的数据到一个csv

# %%
data = {'loc_id':df_y.loc_id,'time_stamp':df_y.time_stamp,'num_of_people':y}
df_ans_submit = pd.DataFrame(data=data)
# df_ans_submit['num_of_people'] = y

df_ans_submit['num_of_people'].describe()

df_ans_submit.shape

columns = ['loc_id','time_stamp','num_of_people']
df_ans_submit.to_csv('Final_2.csv',index=False,columns=columns)
